# %% [markdown]
# **Sentimental Analysis**

# %%
pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from GetOldTweets3) (4.2.6)
# Collecting pyquery>=1.2.10
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1

# %%
import re 
from textblob import TextBlob 
import GetOldTweets3 as got
from matplotlib import pyplot as plt

# %%
def clean_tweet(tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split())

# %% [markdown]
# Tweets about Rishi Kapoor after his death

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('Rishi Kapoor')\
                                           .setSince("2020-04-29")\
                                           .setUntil("2020-05-05")\
                                           .setMaxTweets(100)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
def get_tweet_sentiment(tweet): 
        
        analysis = TextBlob(clean_tweet(tweet)) 

        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# %%
tweets=[]
for tw in tweet: 

  parsed_tweet = {}
  parsed_tweet['text'] = tw.text 
  parsed_tweet['sentiment'] =get_tweet_sentiment(tw.text) 
  if tw.retweets > 0: 
    if parsed_tweet not in tweets: 
      tweets.append(parsed_tweet) 
    else:
      tweets.append(parsed_tweet)

# %%
pive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
nive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
neutral_tweets=[tweet for tweet in tweets if tweet['sentiment']=='neutral']
per_ptweets=len(pive_tweets)/len(tweets)*100
per_ntweets=len(nive_tweets)/len(tweets)*100
per_neutral=len(neutral_tweets)/len(tweets)*100
lab=['Positive','Negative','Neutral']
data=[per_ptweets,per_ntweets,per_neutral]

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = lab) 
plt.show()

# %% [markdown]
# Tweets about Ganesh Chaturthi

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('Ganesh Chaturthi')\
                                           .setSince("2020-08-01")\
                                           .setUntil("2020-09-08")\
                                           .setMaxTweets(100)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
def get_tweet_sentiment(tweet): 
        
        analysis = TextBlob(clean_tweet(tweet)) 

        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# %%
tweets=[]
for tw in tweet: 

  parsed_tweet = {}
  parsed_tweet['text'] = tw.text 
  parsed_tweet['sentiment'] =get_tweet_sentiment(tw.text) 
  if tw.retweets > 0: 
    if parsed_tweet not in tweets: 
      tweets.append(parsed_tweet) 
    else:
      tweets.append(parsed_tweet)

# %%
pive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
nive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
neutral_tweets=[tweet for tweet in tweets if tweet['sentiment']=='neutral']
per_ptweets=len(pive_tweets)/len(tweets)*100
per_ntweets=len(nive_tweets)/len(tweets)*100
per_neutral=len(neutral_tweets)/len(tweets)*100
lab=['Positive','Negative','Neutral']
data=[per_ptweets,per_ntweets,per_neutral]

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = lab) 
plt.show()

# %% [markdown]
# Tweets about Independence day

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('Independence day')\
                                           .setSince("2020-08-01")\
                                           .setUntil("2020-08-20")\
                                           .setMaxTweets(100)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
def get_tweet_sentiment(tweet): 
        
        analysis = TextBlob(clean_tweet(tweet)) 

        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# %%
tweets=[]
for tw in tweet: 

  parsed_tweet = {}
  parsed_tweet['text'] = tw.text 
  parsed_tweet['sentiment'] =get_tweet_sentiment(tw.text) 
  if tw.retweets > 0: 
    if parsed_tweet not in tweets: 
      tweets.append(parsed_tweet) 
    else:
      tweets.append(parsed_tweet)

# %%
pive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
nive_tweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
neutral_tweets=[tweet for tweet in tweets if tweet['sentiment']=='neutral']
per_ptweets=len(pive_tweets)/len(tweets)*100
per_ntweets=len(nive_tweets)/len(tweets)*100
per_neutral=len(neutral_tweets)/len(tweets)*100
lab=['Positive','Negative','Neutral']
data=[per_ptweets,per_ntweets,per_neutral]

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = lab) 
plt.show()
